# %% [markdown]
# # Seaborn可视化

# %% [markdown]
# #### 1.柱形图
# * 导入“iris.csv”数据，使用 hls 颜色空间的画板绘制柱形图
# * 通过可视化图表进行简要分析。

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
data=pd.read_csv('data/iris.csv')
plt.figure(figsize=(10, 6))
unique_species = data['species'].unique()
colors = plt.get_cmap('hsv', len(unique_species))
sns.barplot(x='species', y='sepal_length', data=data,
            palette=colors(range(len(unique_species))))
plt.xlabel('Species')
plt.ylabel('Sepal Length')
plt.title('Sepal Length by Species')
plt.show()
# Out:
# c:\Users\Administrator\anaconda3\envs\anaconda3\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\Administrator\anaconda3\envs\anaconda3\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\Administrator\anaconda3\envs\anaconda3\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):

# %%
import seaborn 
import pandas as pd

iris_data=pd.read_csv('data/iris.csv')

# %% [markdown]
# #### 2.散点图
# * 使用“iris.csv”数据，绘制散点图，使用变量'species'作为分类以不同颜色展示
# * 通过可视化图表进行简要分析。

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(x='sepal_length', y='sepal_width',
                hue='species', data=iris_data)
plt.title('Iris Scatter Plot')
plt.xlabel('Sepal Length')
plt.ylabel('Sepal Width')
plt.show()
# Out:
# c:\Users\Administrator\anaconda3\envs\anaconda3\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\Administrator\anaconda3\envs\anaconda3\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\Administrator\anaconda3\envs\anaconda3\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# ...

# %% [markdown]
# #### 3.直方图
# * 导入“Weatherquality.csv”数据，绘制直方图，同时展示核密度估计图，使用变量'质量等级'作为分类以不同颜色展示
# * 通过可视化图表进行简要分析。

# %%
weather_data = pd.read_excel('data/Weatherquality.xlsx')
plt.rcParams['font.sans-serif'] = ['SimHei']


sns.histplot(data=weather_data, x='质量等级', hue='质量等级', kde=True)
plt.title('Histogram')
plt.xlabel('Quality Level')
plt.ylabel('Frequency')
plt.show()
# Out:
# c:\Users\Administrator\anaconda3\envs\anaconda3\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\Administrator\anaconda3\envs\anaconda3\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\Administrator\anaconda3\envs\anaconda3\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# ...

# %% [markdown]
# #### 4.矩阵散点图
# * 导入“Weatherquality.csv”数据，选取其中5个变量，绘制矩阵散点图
# * 通过可视化图表进行简要分析。

# %%
# Out:
# ...
#   Obtaining dependency information for openpyxl from https://files.pythonhosted.org/packages/c0/da/977ded879c29cbd04de313843e76868e6e13408a94ed6b987245dc7c8506/openpyxl-3.1.5-py2.py3-none-any.whl.metadata
# ...
#   Obtaining dependency information for et-xmlfile from https://files.pythonhosted.org/packages/96/c2/3dd434b0108730014f1b96fd286040dc3bcb70066346f7e01ec2ac95865f/et_xmlfile-1.1.0-py3-none-any.whl.metadata
# ...
#    ---------------------------------------- 0.0/250.9 kB ? eta -:--:--
#    - -------------------------------------- 10.2/250.9 kB ? eta -:--:--
#    ---- ---------------------------------- 30.7/250.9 kB 435.7 kB/s eta 0:00:01
#    ------ -------------------------------- 41.0/250.9 kB 393.8 kB/s eta 0:00:01
#    -------------- ------------------------ 92.2/250.9 kB 585.1 kB/s eta 0:00:01
#    -------------------------- ----------- 174.1/250.9 kB 876.1 kB/s eta 0:00:01
#    ------------------------------- ------ 204.8/250.9 kB 831.5 kB/s eta 0:00:01
# ...

# %% [markdown]
# #### 5.箱型图
# * 导入“Weatherquality.csv”数据，绘制小提琴图
# * 通过可视化图表进行简要分析。

# %%
plt.figure(figsize=(10, 6))
sns.violinplot(data=weather_data)
plt.title('Weather Quality Violin Plot')
plt.xlabel('Quality Level')
plt.ylabel('Distribution')
plt.show()
# Out:
# c:\Users\Administrator\anaconda3\envs\anaconda3\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\Administrator\anaconda3\envs\anaconda3\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\Administrator\anaconda3\envs\anaconda3\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# ...

# %% [markdown]
# #### 6.热力图
# * 生成相关系数矩阵，绘制热力图
# weather_data

# %%
corr_matrix = weather_data.iloc[:,3:].corr()

plt.figure(figsize=(10, 8))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm')
plt.title('Correlation Heatmap')
plt.show()

# %%
weather_data
# Out:
#             日期  AQI  质量等级  PM$\mathrm{_{2.5}}$  PM10  S$\mathrm{O_2}$   CO  \
# 0   2019-01-01   64     良                   46    37                5  0.7
# 1   2019-01-02  100     良                   75     0                6  1.0
# 2   2019-01-03   98     良                   73    72                5  1.0
# 3   2019-01-04   63     良                   45    25                4  1.0
# 4   2019-01-05  188  中度污染                  141     0                5  1.2
# ..         ...  ...   ...                  ...   ...              ...  ...
# 360 2019-12-27  123  轻度污染                   93    90                9  1.4
# 361 2019-12-28   97     良                   72    68                8  1.1
# 362 2019-12-29   94     良                   70    73               13  1.4
# 363 2019-12-30  122  轻度污染                   92    76                7  1.2
# 364 2019-12-31  155  中度污染                  118    87                5  1.3
#
#      N$\mathrm{O_2}$  O3_8h
# 0                 24     37
# ...
